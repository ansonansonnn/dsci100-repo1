# %%
library(tidyverse)
library(repr)
library(tidymodels)
library(cowplot)
options(repr.matrix.max.rows = 6)
source('cleanup.R')

# %%
players <- read_csv("data/players.csv")
players

# %%
sessions <- read_csv("data/sessions.csv")
sessions

# %% [markdown]
# 1) Data Description
